# %%
#Bilge Kağan Şenol
#19070001011

# %% [markdown]
# **This is my best performance metrics after my result you can examine how i decieded to k values**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#OUTPUT FOR  BEST K VALUE
Metrics and Totals for k=20:
Class 1: Metrics = {'precision': 0.47318924442873855, 'recall': 0.5079298245614036, 'f_score': 0.4890331996134655, 'accuracy': 0.7326666666666668}
Class 2: Metrics = {'precision': 0.5847792088591369, 'recall': 0.6992732558139536, 'f_score': 0.6367331814146711, 'accuracy': 0.6576666666666666}
Class 3: Metrics = {'precision': 0.5080513761157097, 'recall': 0.3438048245614035, 'f_score': 0.40913784300896827, 'accuracy': 0.6849999999999999}
Total TP: {1: 384, 2: 900, 3: 329}
Total FP: {1: 430, 2: 640, 3: 317}
Total FN: {1: 372, 2: 387, 3: 628}

# %%
#######################################################################################################################################################################################################

# %% [markdown]
# **HOW I DECİEDED  K VALUES**

# %% [markdown]
#  **First i make my all testing  with these  k values :
# k_values = [1,3,5,7,9,11,13,15,17,18,20]**
#
#
# accuracy is increasing we don't see any peek

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# But we can see  our accuraty is increasing so  i  start to increase k values
#
#
# so i decieded to  try for  these values to see a peek
#
#
# k_values = [22,24,26,28,30,32,34,36,38,40,42,44,46,48,50]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# I deciede on 20 for k values  because graph shows  accuracy on line after 20 .

# %%
#THESE ARE MY DETAILED RESULTS FOR K VALUES

# %% [markdown]
# THESE ARE FOR :
# k_values = [1,3,5,7,9,11,13,15,17,18,20]
#
#
#
# Metrics for k=1:
# Class 1: {'precision': 0.41545336216451734, 'recall': 0.5700701754385965, 'f_score': 0.4802261826410271, 'accuracy': 0.6886666666666665}
# Class 2: {'precision': 0.6366678478705446, 'recall': 0.49645106589147286, 'f_score': 0.5568609824518911, 'accuracy': 0.6616666666666666}
# Class 3: {'precision': 0.4260457623767365, 'recall': 0.42314692982456137, 'f_score': 0.42410381159444466, 'accuracy': 0.633}
#
# Metrics for k=3:
# Class 1: {'precision': 0.37908443558384786, 'recall': 0.6665964912280702, 'f_score': 0.48282365593423265, 'accuracy': 0.6399999999999999}
# Class 2: {'precision': 0.6570443365880836, 'recall': 0.4801598837209302, 'f_score': 0.5537942659421561, 'accuracy': 0.669}
# Class 3: {'precision': 0.45927439357405253, 'recall': 0.35005482456140347, 'f_score': 0.39640814633629384, 'accuracy': 0.6623333333333334}
#
# Metrics for k=5:
# Class 1: {'precision': 0.4005644985908915, 'recall': 0.622859649122807, 'f_score': 0.48686474838166305, 'accuracy': 0.6689999999999999}
# Class 2: {'precision': 0.6226595411841365, 'recall': 0.5772468507751938, 'f_score': 0.5979173272639432, 'accuracy': 0.6673333333333333}
# Class 3: {'precision': 0.49205619158211134, 'recall': 0.3228837719298246, 'f_score': 0.38870124152705987, 'accuracy': 0.6789999999999999}
#
# Metrics for k=7:
# Class 1: {'precision': 0.43460979099754277, 'recall': 0.5765964912280701, 'f_score': 0.49500343852405226, 'accuracy': 0.704}
# Class 2: {'precision': 0.6086108634355668, 'recall': 0.6068253391472869, 'f_score': 0.6065187599021655, 'accuracy': 0.663}
# Class 3: {'precision': 0.4652997815639413, 'recall': 0.3458223684210527, 'f_score': 0.39587711872089393, 'accuracy': 0.665}
#
# Metrics for k=9:
# Class 1: {'precision': 0.4315479570033552, 'recall': 0.5608245614035088, 'f_score': 0.4874051654522115, 'accuracy': 0.7026666666666668}
# Class 2: {'precision': 0.6063544251663189, 'recall': 0.6083333333333334, 'f_score': 0.6064108864494626, 'accuracy': 0.6623333333333333}
# Class 3: {'precision': 0.4512453696309118, 'recall': 0.34158991228070174, 'f_score': 0.38798414337891535, 'accuracy': 0.6576666666666666}
#
# Metrics for k=11:
# Class 1: {'precision': 0.44466933427733324, 'recall': 0.5383684210526316, 'f_score': 0.48645051151825064, 'accuracy': 0.7133333333333334}
# Class 2: {'precision': 0.6017288959122462, 'recall': 0.6572734980620155, 'f_score': 0.6277590470835942, 'accuracy': 0.666}
# Class 3: {'precision': 0.47633541507600763, 'recall': 0.33539473684210525, 'f_score': 0.3926413314218773, 'accuracy': 0.6699999999999999}
#
# Metrics for k=13:
# Class 1: {'precision': 0.45590841783196456, 'recall': 0.5185087719298246, 'f_score': 0.4845917278856449, 'accuracy': 0.7223333333333334}
# Class 2: {'precision': 0.5983720619274868, 'recall': 0.6650859980620155, 'f_score': 0.6294209130579216, 'accuracy': 0.6646666666666666}
# Class 3: {'precision': 0.4808571216405723, 'recall': 0.3542543859649122, 'f_score': 0.40696498505672246, 'accuracy': 0.671}
#
# Metrics for k=15:
# Class 1: {'precision': 0.4579359140158579, 'recall': 0.5157894736842105, 'f_score': 0.48455252788195907, 'accuracy': 0.724}
# Class 2: {'precision': 0.5939483105794843, 'recall': 0.6604408914728683, 'f_score': 0.6249917501151511, 'accuracy': 0.6603333333333334}
# Class 3: {'precision': 0.48461347682068173, 'recall': 0.36157894736842106, 'f_score': 0.41345947811450373, 'accuracy': 0.673}
#
# Metrics for k=17:
# Class 1: {'precision': 0.472029889442667, 'recall': 0.5158596491228071, 'f_score': 0.4923003928016524, 'accuracy': 0.732}
# Class 2: {'precision': 0.5927696728828677, 'recall': 0.6860949612403101, 'f_score': 0.6355992290770518, 'accuracy': 0.663}
# Class 3: {'precision': 0.4970261918140899, 'recall': 0.3543311403508772, 'f_score': 0.41223211393403025, 'accuracy': 0.6796666666666666}
#
# Metrics for k=18:
# Class 1: {'precision': 0.466663021574034, 'recall': 0.5172456140350877, 'f_score': 0.49003194854094634, 'accuracy': 0.7286666666666667}
# Class 2: {'precision': 0.5907143360838375, 'recall': 0.6806201550387597, 'f_score': 0.6321305220337023, 'accuracy': 0.6603333333333333}
# Class 3: {'precision': 0.4976090850991901, 'recall': 0.3522258771929825, 'f_score': 0.4114157667797282, 'accuracy': 0.6803333333333333}
#
# Metrics for k=20:
# Class 1: {'precision': 0.47318924442873855, 'recall': 0.5079298245614036, 'f_score': 0.4890331996134655, 'accuracy': 0.7326666666666668}
# Class 2: {'precision': 0.5847792088591369, 'recall': 0.6992732558139536, 'f_score': 0.6367331814146711, 'accuracy': 0.6576666666666666}
# Class 3: {'precision': 0.5080513761157097, 'recall': 0.3438048245614035, 'f_score': 0.40913784300896827, 'accuracy': 0.6849999999999999}
#
# Metrics for k=22:
# Class 1: {'precision': 0.47409869320725273, 'recall': 0.4881578947368421, 'f_score': 0.48038701076485885, 'accuracy': 0.7343333333333334}
# Class 2: {'precision': 0.5762179611157481, 'recall': 0.700030281007752, 'f_score': 0.6320130024967421, 'accuracy': 0.6503333333333333}
# Class 3: {'precision': 0.4914641256941784, 'recall': 0.3364364035087719, 'f_score': 0.3987944281298689, 'accuracy': 0.6766666666666666}
#
# Metrics for k=24:
# Class 1: {'precision': 0.4792130505378426, 'recall': 0.4881228070175439, 'f_score': 0.4830856922581125, 'accuracy': 0.7373333333333333}
# Class 2: {'precision': 0.5760224472473586, 'recall': 0.7155523255813954, 'f_score': 0.6381163585101369, 'accuracy': 0.6519999999999999}
# Class 3: {'precision': 0.48619294842711624, 'recall': 0.3197478070175439, 'f_score': 0.38505014250478964, 'accuracy': 0.6746666666666667}
#
# Metrics for k=26:
# Class 1: {'precision': 0.48316005550781815, 'recall': 0.4762105263157895, 'f_score': 0.47884841236541825, 'accuracy': 0.7396666666666667}
# Class 2: {'precision': 0.5721655297246324, 'recall': 0.7241157945736434, 'f_score': 0.6389099267097411, 'accuracy': 0.649}
# Class 3: {'precision': 0.4740774659238106, 'recall': 0.30722587719298244, 'f_score': 0.37146502359851985, 'accuracy': 0.6686666666666665}
#
# Metrics for k=28:
# Class 1: {'precision': 0.48200626557178133, 'recall': 0.47217543859649125, 'f_score': 0.4760893088501182, 'accuracy': 0.7396666666666667}
# Class 2: {'precision': 0.5688167805737931, 'recall': 0.7334544573643411, 'f_score': 0.6404382084735206, 'accuracy': 0.647}
# Class 3: {'precision': 0.4777889126024917, 'recall': 0.29986842105263156, 'f_score': 0.36716976866567075, 'accuracy': 0.6719999999999999}
#
# Metrics for k=30:
# Class 1: {'precision': 0.48765411894203253, 'recall': 0.4801578947368421, 'f_score': 0.4826197376907836, 'accuracy': 0.7423333333333333}
# Class 2: {'precision': 0.572061307748972, 'recall': 0.7373849321705426, 'f_score': 0.6440351317302804, 'accuracy': 0.6506666666666667}
# Class 3: {'precision': 0.4746841735977484, 'recall': 0.2957127192982456, 'f_score': 0.36278705214337237, 'accuracy': 0.6703333333333333}
#
# Metrics for k=32:
# Class 1: {'precision': 0.4909341994556765, 'recall': 0.47094736842105256, 'f_score': 0.47984329831222594, 'accuracy': 0.7439999999999999}
# Class 2: {'precision': 0.5690089398932721, 'recall': 0.7521196705426357, 'f_score': 0.647648648641566, 'accuracy': 0.6489999999999999}
# Class 3: {'precision': 0.48971290999371353, 'recall': 0.29158991228070175, 'f_score': 0.36409993766992677, 'accuracy': 0.6756666666666666}
#
# Metrics for k=34:
# Class 1: {'precision': 0.4948570900986162, 'recall': 0.4655964912280702, 'f_score': 0.4787023494829187, 'accuracy': 0.7463333333333333}
# Class 2: {'precision': 0.570025863688778, 'recall': 0.7575763081395348, 'f_score': 0.6502969119214811, 'accuracy': 0.6506666666666667}
# Class 3: {'precision': 0.4939724331340304, 'recall': 0.29677631578947367, 'f_score': 0.36956260513227707, 'accuracy': 0.6769999999999999}
#
# Metrics for k=36:
# Class 1: {'precision': 0.49120231693501115, 'recall': 0.4617192982456141, 'f_score': 0.47476006617698, 'accuracy': 0.7446666666666666}
# Class 2: {'precision': 0.5686906867354544, 'recall': 0.7568192829457363, 'f_score': 0.6490343384972042, 'accuracy': 0.6493333333333332}
# Class 3: {'precision': 0.48567839117360706, 'recall': 0.29153508771929826, 'f_score': 0.3631461189983093, 'accuracy': 0.6739999999999999}
#
# Metrics for k=38:
# Class 1: {'precision': 0.4954781506192171, 'recall': 0.4511052631578948, 'f_score': 0.4705663323047271, 'accuracy': 0.747}
# Class 2: {'precision': 0.5613392727501761, 'recall': 0.7614825581395348, 'f_score': 0.6458021059775716, 'accuracy': 0.642}
# Class 3: {'precision': 0.4846442132417289, 'recall': 0.2853179824561404, 'f_score': 0.35737836038446597, 'accuracy': 0.6736666666666666}
#
# Metrics for k=40:
# Class 1: {'precision': 0.502426360073251, 'recall': 0.45112280701754387, 'f_score': 0.47392364612231275, 'accuracy': 0.7500000000000001}
# Class 2: {'precision': 0.5670846691506622, 'recall': 0.7832606589147286, 'f_score': 0.6575303147408041, 'accuracy': 0.6503333333333334}
# Class 3: {'precision': 0.5006989624275356, 'recall': 0.28423245614035086, 'f_score': 0.36157534299994365, 'accuracy': 0.6803333333333332}
#
# Metrics for k=42:
# Class 1: {'precision': 0.4954381689488717, 'recall': 0.4511052631578947, 'f_score': 0.4705311009896837, 'accuracy': 0.7466666666666666}
# Class 2: {'precision': 0.5606108001406562, 'recall': 0.7716024709302325, 'f_score': 0.6490097315977081, 'accuracy': 0.6423333333333333}
# Class 3: {'precision': 0.4817969974462901, 'recall': 0.27168859649122806, 'f_score': 0.34652715128041894, 'accuracy': 0.6736666666666666}
#
# Metrics for k=44:
# Class 1: {'precision': 0.4984642164908931, 'recall': 0.44582456140350873, 'f_score': 0.4685052091029231, 'accuracy': 0.7476666666666667}
# Class 2: {'precision': 0.5580058575836683, 'recall': 0.7817102713178293, 'f_score': 0.6508968117732439, 'accuracy': 0.6406666666666667}
# Class 3: {'precision': 0.4987276953453148, 'recall': 0.2706359649122807, 'f_score': 0.3492123638926234, 'accuracy': 0.6796666666666666}
#
# Metrics for k=46:
# Class 1: {'precision': 0.502574751510928, 'recall': 0.4458771929824561, 'f_score': 0.4706984855594728, 'accuracy': 0.7496666666666667}
# Class 2: {'precision': 0.5523664867265952, 'recall': 0.7754481589147286, 'f_score': 0.6448291213515229, 'accuracy': 0.6343333333333334}
# Class 3: {'precision': 0.49195613685697503, 'recall': 0.26648026315789475, 'f_score': 0.343417401713331, 'accuracy': 0.6759999999999999}
#
# Metrics for k=48:
# Class 1: {'precision': 0.5237200838444687, 'recall': 0.45119298245614037, 'f_score': 0.48178187082448504, 'accuracy': 0.7573333333333334}
# Class 2: {'precision': 0.5555282349493507, 'recall': 0.7886809593023255, 'f_score': 0.6515731260067713, 'accuracy': 0.6386666666666666}
# Class 3: {'precision': 0.5072864351597179, 'recall': 0.2737828947368421, 'f_score': 0.35417129853149565, 'accuracy': 0.6826666666666668}
#
# Metrics for k=50:
# Class 1: {'precision': 0.5171134039902796, 'recall': 0.44056140350877193, 'f_score': 0.473452420358876, 'accuracy': 0.755}
# Class 2: {'precision': 0.5495551854118267, 'recall': 0.7925811531007751, 'f_score': 0.6487872742214522, 'accuracy': 0.6323333333333333}
# Class 3: {'precision': 0.518346153704163, 'recall': 0.2685635964912281, 'f_score': 0.35243219482215815, 'accuracy': 0.686}
